# %% [markdown]
# <a href="https://colab.research.google.com/github/19K41A05F3/AI/blob/main/Assignment_2_19K41A05F3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assignment-2
import numpy as np
x=np.random.uniform(-10,10)
eta=0.001
iter_max=300

# %%
iter=1
while iter<=iter_max :
 slope = 4*x*x*x + 6*x
 step_length = (-eta) * slope
 x=x+step_length
 iter=iter+1 
print("control variable = ",round(x))
obj = ((x*x*x*x)+(3*x*x)+10)
print("objective function = ",round(obj))
# Out:
# control variable =  0
# objective function =  10

# %% [markdown]
# ![AI_Assignment2_5F3.jpeg](data:image/jpeg;base64,...)
